# %% [markdown]
# # Flight Price prediction

# %%
#importing basics libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt     #we only doing feature engineering in this
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_excel('Data_Train.xlsx')
dataset.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
##if we want to quicly wants to see the entire dataset

# %%
dataset.info()   #with all the inforamtion i have, i want to predict the price of the ticket.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
dataset.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
##what type of feature engineering we can do to make this data, more meaningful
#if i tell to my location, that my location is in banglore it wont be able to load the loation, it wont be able to understand.
#model only understand numbers
#if have a Date_of_Journey and it is a object type, ihave to do the splitting and convert it into the numbers

# %%
#converting date of journey into numbers, it avalible in object.

# %%
dataset["Date_of_Journey"][1][0:2]
# Out:
# '1/'

# %%
dataset
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
a="prnajl/shara"

# %%
a.split("/")
# Out:
# ['prnajl', 'shara']

# %%
dataset['Date']=dataset['Date_of_Journey'].str.split('/').str[0]
dataset['Month']=dataset['Date_of_Journey'].str.split('/').str[1]         #we can also do this by using lambda funbcion
dataset['Year']=dataset['Date_of_Journey'].str.split('/').str[2]

# %%
#by using labmbda function
dataset['Date_of_Journey'].apply(lambda x:x.split("/")[0])
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date_of_Journey, Length: 10683, dtype: object

# %%
dataset.dtypes #still this is object, we have to convert it into int
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Date               object
# Month              object
# Year               object
# dtype: object

# %%
dataset
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dataset['Date']=dataset['Date'].astype(int)
dataset['Month']=dataset['Month'].astype(int)
dataset['Year']=dataset['Year'].astype(int)

# %%
dataset.dtypes   #changed.
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Date                int32
# Month               int32
# Year                int32
# dtype: object

# %%
#dateof journey is not required now/

# %%
dataset.drop("Date_of_Journey",axis=1,inplace=True)   #axis is 1 columns

# %%
dataset.head(10)
# Out:
#              Airline    Source Destination                  Route Dep_Time  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR    09:00
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    18:55
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:00
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:55
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    11:25
#
#    Arrival_Time Duration Total_Stops              Additional_Info  Price  \
# ...

# %%
#in arrival time we have mar,jun.. we have to clear this first. 
#to extract01:10 22 Ma,13:15

# %%
A="PRANJAL hero SHARMAA"

# %%
A.split("hero")
# Out:
# ['PRANJAL,,,,,SHARMAA']

# %%
dataset["Arrival_Time"].str.split(' ')[0][0]
# Out:
# '01:10'

# %%
dataset['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dataset['Arrival_Time'].str.split(' ').str[0].str.split(":").str[0]
# Out:
# 0        01
# 1        13
# 2        04
# 3        23
# 4        21
#          ..
# 10678    22
# 10679    23
# 10680    11
# 10681    14
# 10682    19
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dataset['Arrival_Time'].str.split(' ').str[0].str.split(":").str[1]
# Out:
# 0        10
# 1        15
# 2        25
# 3        30
# 4        35
#          ..
# 10678    25
# 10679    20
# 10680    20
# 10681    10
# 10682    15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
##try to get arrival hour and arrival minutes as new columns and then drop Arrival_Time	 column

# %%
dataset["arrival_hour"]=dataset['Arrival_Time'].str.split(' ').str[0].str.split(":").str[0]

# %%
dataset["arrival_minute"]=dataset['Arrival_Time'].str.split(' ').str[0].str.split(":").str[1]

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# ...

# %%
dataset.drop("Arrival_Time",axis=1,inplace=True)

# %%
##now converting it into integer.

# %%
dataset["arrival_hour"]=dataset["arrival_hour"].astype(int)

# %%
dataset["arrival_minute"]=dataset["arrival_minute"].astype(int)

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#       Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# ...

# %%
##now we will do the same for dep_time
dataset["dep_hour"]=dataset["Dep_Time"].str.split(":").str[0]

# %%
dataset["dep_min"]=dataset["Dep_Time"].str.split(":").str[1]

# %%
dataset.drop("Dep_Time",axis=1,inplace=True)

# %%
dataset.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#   Total_Stops Additional_Info  Price  Date  Month  Year  arrival_hour  \
# 0    non-stop         No info   3897    24      3  2019             1
# 1     2 stops         No info   7662     1      5  2019            13
#
#    arrival_minute dep_hour dep_min
# 0              10       22      20
# 1              15       05      50

# %%
dataset.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Route              object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Date                int32
# Month               int32
# Year                int32
# arrival_hour        int32
# arrival_minute      int32
# dep_hour           object
# dep_min            object
# dtype: object

# %%
dataset["dep_hour"]=dataset["dep_hour"].astype(int)
dataset["dep_min"]=dataset["dep_min"].astype(int)

# %%
dataset.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Route              object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Date                int32
# Month               int32
# Year                int32
# arrival_hour        int32
# arrival_minute      int32
# dep_hour            int32
# dep_min             int32
# dtype: object

# %%
#for duration we also have to do this.
dataset["duration_hour"]=dataset["Duration"].str.split("h").str[0]

# %%
dataset["duration_minute"]=dataset["Duration"].str.split(" ").str[1].str.split("m").str[0]

# %%
dataset.head(10)
# Out:
#              Airline    Source Destination                  Route Duration  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR   2h 25m
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  15h 30m
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL   21h 5m
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  25h 30m
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK   7h 50m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0    non-stop                      No info   3897    24      3  2019
# ...

# %%
dataset.drop("Duration",axis=1,inplace=True)

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Total_Stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
# ...            ...       ...         ...                    ...         ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    non-stop
# 10679    Air India   Kolkata    Banglore              CCU → BLR    non-stop
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    non-stop
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    non-stop
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK     2 stops
#
# ...

# %%
#filling nan value of minutes with o

# %%
dataset["duration_minute"].fillna(0,inplace=True)

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Total_Stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
# ...            ...       ...         ...                    ...         ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    non-stop
# 10679    Air India   Kolkata    Banglore              CCU → BLR    non-stop
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    non-stop
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    non-stop
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK     2 stops
#
# ...

# %%
dataset.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Route              object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Date                int32
# Month               int32
# Year                int32
# arrival_hour        int32
# arrival_minute      int32
# dep_hour            int32
# dep_min             int32
# duration_hour      object
# duration_minute    object
# dtype: object

# %%
#dataset["duration_hour"]=dataset["duration_hour"].astype(int)
dataset["duration_minute"]=dataset["duration_minute"].astype(int)

# %%
#instwead of this do this entirely in minutes
# Out:
# 0

# %%
dataset["Total_Stops"].unique()   #we can replace it with 0,1,2,3,4.
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
#we will do this by map function.
#this will get change to zero
#dataset["Total_Stops"].map({"non stop":0})

# %%
dataset["Total_Stops"].mode()
# Out:
# 0    1 stop
# Name: Total_Stops, dtype: object

# %%
dataset['Total_Stops']=dataset['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})#why we replaced nan with one, becasue the mode is 1.

# %%
dataset.head(4)
# Out:
#        Airline    Source Destination                  Route  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL          0.0
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK          2.0
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR          1.0
#
#   Additional_Info  Price  Date  Month  Year  arrival_hour  arrival_minute  \
# 0         No info   3897    24      3  2019             1              10
# 1         No info   7662     1      5  2019            13              15
# 2         No info  13882     9      6  2019             4              25
# 3         No info   6218    12      5  2019            23              30
#
#    dep_hour  dep_min duration_hour  duration_minute
# 0        22       20             2               50
# 1         5       50             7               25
# 2         9       25            19                0
# ...

# %%
#route is captured by the total_stops,so we will drop it

# %%
dataset.drop("Route",axis=1,inplace=True)

# %%
dataset.head(2)  #by map we are getting floating value becasuse map by deafualt gives the floating value.
# Out:
#      Airline    Source Destination  Total_Stops Additional_Info  Price  Date  \
# 0     IndiGo  Banglore   New Delhi          0.0         No info   3897    24
# 1  Air India   Kolkata    Banglore          2.0         No info   7662     1
#
#    Month  Year  arrival_hour  arrival_minute  dep_hour  dep_min duration_hour  \
# 0      3  2019             1              10        22       20             2
# 1      5  2019            13              15         5       50             7
#
#    duration_minute
# 0               50
# 1               25

# %%
#lets work on airline
dataset["Airline"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
dataset["Source"].unique()   #if we assign b as 0, k as 1, d as 2, chennai as 3, mumbai as 4...and then we run our machine learing code it will think that kolkata is greater than banglore
#it will think that mumbai is the biggest model, so we have to give more importance to this, model is the thing that its not going to understand
#this is the prblem with label encoding
#so that is the reason we do one hot encoding
#so we will create 5 columns       banaglore(0),  kolakata(1),delhi(2),chennai(3),mumbai(4)
#first row is having banagalore     banglaore[1],0,0,0,0    #if all values are zero apart from 0th column, then we can delete the first column
#second row we have kolakta        0,kolakata[1],0,0,0 
#this is one hot encoding and we achieve it through pd.get_dummies
#also a library on sk.learn which is called as one hot scaler,ohe
#if we reomve the first column , then in the first row the values will be 0,0,0,0---> then also it will belong to banagalore
#this property is drop_first=True---->mean to delte the first row.
#whever ordinal ranking is there, we dont do it in label encoding
#if we have rank, suppose rank1,rank2,rank3 then we will do label encoding.becuase the values are ordinal
#qualification->phd,be,masters,10,12---->we will use label encoding
#we have week days-->sat,sun,monday----> we will one hot encoding
#we have to predict the persn"s energy level based on this days.-->lab
#saturday and sunday the enrgy will be husghest, monday the energy will be good and gradually the energy will go down.
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
dataset["Destination"].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
#desitantion will be more as copompared to source
dataset["Additional_Info"].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
#label encoding-->we are going to assing 0,1,2,3,4,5 etc. on categorical value.
#later it can be converted into dummies values
dataset=pd.get_dummies(dataset,columns=["Airline","Source","Destination","Additional_Info"],drop_first=True)
#one hot encoding

# %%
# Out:
# dtype('float64')
